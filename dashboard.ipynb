# %%
# Make sure code changes to local Python files are
# loaded automatically when changed.
# %load_ext autoreload
# %autoreload 2

# %%
from display.interface import MainDashboard

dashboard = MainDashboard()
dashboard.app
